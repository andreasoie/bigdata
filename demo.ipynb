# %%
from pytrends.request import TrendReq
from matplotlib import pyplot as plt
import pandas as pd

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# Vizu settings
# %matplotlib inline
plt.rcParams['font.size'] = 16
plt.rcParams['figure.figsize'] = (10, 6)

# Local imports
from utils import load_countries, plot_history, histories_to_pandas
from search_engine import SearchEngine

# reproducibility
import random
random.seed(1337)

# %%
COUNTRY_DIR = "docs/countries.txt"
COUNTRY_IGNORE_DIR = "docs/ignore.txt"
LANGUAGE = 'en-US'
TIME_ZONE = 360

search_engine = SearchEngine(
    pytrends = TrendReq(hl=LANGUAGE, tz=TIME_ZONE),
    supported_countries = load_countries(filename=COUNTRY_DIR, ignore=COUNTRY_IGNORE_DIR),
    fetch_interval = 1
)

# %% [markdown]
# ### Example query: 1
#
# ```python
# YEAR = 2019
# SEARCH_TERMS = ["ski"]
# SEARCH_COUNTRIES = ["Norway", "Sweden", "Denmark"]
# ```
#
# ### Example query: 2
#
# ```python
# YEAR = 2019
# SEARCH_TERMS = ["ski"]
# SEARCH_COUNTRIES = 3
# # 0: int .. returns all available countries
# # 3: int .. returns 3 random countries
# # X: int .. returns X random countries
# ```
#
# ### Example query: 3
#
# ```python
# YEAR = 2019
# SEARCH_TERMS = ["cheese", "wine"]
# SEARCH_COUNTRIES = ["Italy", "France", "Spain"]
# ```

# %%
YEAR = 2010
SEARCH_TERMS = ["ski"]
SEARCH_COUNTRIES = ["Norway"]

# %% [markdown]
# ### Query the Google API via our Search Engine

# %%
history_trends = search_engine.get_daily_trends_by_year(
    search_terms=SEARCH_TERMS,
    year=YEAR,
    countries=SEARCH_COUNTRIES
)
# Out:
# Fetching trends: 100%|██████████| 1/1 [00:03<00:00,  3.17s/it]

# %% [markdown]
# #### Display trends

# %%
plot_history(history_trends, SEARCH_TERMS)

# %% [markdown]
# ## Merge Trends to DataFrame

# %%
YEARS = [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020]

total_trends = []


for year in YEARS:

    history_trends = search_engine.get_daily_trends_by_year(
        search_terms=SEARCH_TERMS,
        year=year,
        countries=SEARCH_COUNTRIES
    )

    trends_df = histories_to_pandas(history_trends)

    total_trends.append(trends_df)

ski_trends = pd.concat(total_trends)
# Out:
# Fetching trends: 100%|██████████| 1/1 [00:03<00:00,  3.18s/it]
# Fetching trends: 100%|██████████| 1/1 [00:03<00:00,  3.35s/it]
# Fetching trends: 100%|██████████| 1/1 [00:03<00:00,  3.10s/it]
# Fetching trends: 100%|██████████| 1/1 [00:03<00:00,  3.19s/it]
# Fetching trends: 100%|██████████| 1/1 [00:03<00:00,  3.20s/it]
# Fetching trends: 100%|██████████| 1/1 [00:04<00:00,  4.02s/it]
# Fetching trends: 100%|██████████| 1/1 [00:03<00:00,  3.51s/it]
# Fetching trends: 100%|██████████| 1/1 [00:03<00:00,  3.66s/it]
# Fetching trends: 100%|██████████| 1/1 [00:03<00:00,  3.14s/it]
# Fetching trends: 100%|██████████| 1/1 [00:03<00:00,  3.15s/it]
# Fetching trends: 100%|██████████| 1/1 [00:03<00:00,  3.27s/it]

# %%
ski_trends.head()
# Out:
#         date  ski country
# 0 2010-01-01   77  Norway
# 1 2010-01-02   63  Norway
# 2 2010-01-03   86  Norway
# 3 2010-01-04  100  Norway
# 4 2010-01-05   62  Norway

# %%
ski_trends.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4018 entries, 0 to 365
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   date     4018 non-null   datetime64[ns]
#  1   ski      4018 non-null   int32
#  2   country  4018 non-null   object
# dtypes: datetime64[ns](1), int32(1), object(1)
# memory usage: 109.9+ KB

# %%
plt.figure(figsize=(20, 6))
plt.plot(ski_trends["date"], ski_trends["ski"], label='ski')
plt.title("Skiing trends")
plt.xlabel("Date")
plt.ylabel("Interest")
plt.legend()

# %% [markdown]
# ### TODO
#
# - Check if all data is valid, and doesn't contain NaN values (?)
# - Save DataFrame to DataBase (?)
#   - what column_names to follow?
#   - allow blank spaces?
#   - etc etc..

# %% [markdown]
# ### Optionally: save to CSV

# %%
ski_trends.to_csv(f"trends-{YEAR}.csv", index=False)

# %% [markdown]
# #### M

# %%
from sklearn.cluster import KMeans
